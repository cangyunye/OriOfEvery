# %% [markdown]
# # k-近邻算法一般流程
# 1. 收集数据，并格式化
# 2. 距离计算
# 3. 分析数据
# 4. 测试算法，即准确度

# %%
#科学计算工具包
from numpy import *
#运算符模块
import operator 

def createDataSet():
    #用于创建数据集合标签
    group = array([[1.0,1.1],[1.0,1.0],[0,0],[0,0.1]])
    labels = ['A','A','B','B']
    return group,labels
createDataSet()
# Out:
# (array([[1. , 1.1],
#         [1. , 1. ],
#         [0. , 0. ],
#         [0. , 0.1]]), ['A', 'A', 'B', 'B'])

# %% [markdown]
# 对未知类别属性的数据集中的每个点依次执行以下操作：
# 1. 计算已知类别数据集中的点与测试点之间的距离。
# 2. 按照距离递增次序排序。
# 3. 选取与测试点距离最小的k个点。
# 4. 确定前k个点所在类别的出现频率。
# 5. 返回前k个点出现频率最高的类别作为当前点的预测分类。

# %%
def classify0(inX,dataSet,labels,k):
    #第n维，即表示列表符号"[]"第几层，从1层开始，第1维表示[a,b,c]的a,b,c等3个项
    #统计第1维项数量，即数据的行数
    dataSetSize = dataSet.shape[0]
    #将输入坐标通过tile，扩大为样本数据的行数，然后每行减去对应行的样本
    diffMat = tile(inX,(dataSetSize,1)) - dataSet
    #求矩阵各项平方
    sqDiffMat = diffMat**2
    #对第2维项求和,即对所有列求和
    sqDistances = sqDiffMat.sum(axis=1)
    #取根号
    distances = sqDistances**0.5
    #按照距离递增排序,返回索引号
    sortedDistIndicies = distances.argsort()
    classCount = {}
    #选择距离最小的k个点
    for i in range(k):
        #排序的前k个点对应的类
        voteIlabel = labels[sortedDistIndicies[i]]
        #字典对每个类的统计
        classCount[voteIlabel] = classCount.get(voteIlabel,0) + 1
    #依据字典的值itemgetter(1)，即统计数进行排序
    sortedClassCount = sorted(classCount.items(),key=operator.itemgetter(1),reverse=True)
    #返回最大统计数
    return sortedClassCount[0][0]
group,labels = createDataSet()   
classify0([0,0],group,labels,3)
# Out:
# 'B'

# %% [markdown]
# # 读取文本到列表
#
# 飞行公里  玩游戏所耗时间百分比   每周冰淇淋体积   喜欢度

# %%
def file2matrix(filename):
    fr = open(filename)
    love_dictionary = {'largeDoses':3, 'smallDoses':2, 'didntLike':1}
    arrayOLines = fr.readlines()
    numberOfLines = len(arrayOLines)
    returnMat = zeros((numberOfLines,3))
    classLabelVector = []
    index = 0
    for line in arrayOLines:
        #清除行前后的空格以及换行符
        line = line.strip()
        #根据\t分组
        listFromLine = line.split('\t')
        returnMat[index,:] = listFromLine[0:3]
        if listFromLine[-1].isdigit():
            classLabelVector.append((int(listFromLine[-1])))
        else:
            classLabelVector.append(love_dictionary.get(listFromLine[-1]))
        index += 1
    return returnMat,classLabelVector
file2matrix('datingTestSet.txt')
# Out:
# (array([[4.0920000e+04, 8.3269760e+00, 9.5395200e-01],
#         [1.4488000e+04, 7.1534690e+00, 1.6739040e+00],
#         [2.6052000e+04, 1.4418710e+00, 8.0512400e-01],
#         ...,
#         [2.6575000e+04, 1.0650102e+01, 8.6662700e-01],
#         [4.8111000e+04, 9.1345280e+00, 7.2804500e-01],
#         [4.3757000e+04, 7.8826010e+00, 1.3324460e+00]]),
#  [3,
#   2,
#   1,
#   1,
#   1,
#   1,
#   3,
#   3,
#   1,
#   3,
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   1,
#   1,
#   2,
#   3,
#   2,
#   1,
#   2,
#   3,
#   2,
#   3,
#   2,
#   3,
#   2,
#   1,
#   3,
#   1,
#   3,
#   1,
#   2,
#   1,
#   1,
#   2,
#   3,
#   3,
#   1,
#   2,
#   3,
#   3,
#   3,
#   1,
#   1,
#   1,
#   1,
#   2,
#   2,
#   1,
#   3,
#   2,
#   2,
#   2,
#   2,
#   3,
#   1,
#   2,
#   1,
#   2,
#   2,
#   2,
#   2,
#   2,
#   3,
#   2,
#   3,
#   1,
#   2,
#   3,
#   2,
#   2,
#   1,
#   3,
#   1,
#   1,
#   3,
#   3,
#   1,
#   2,
#   3,
#   1,
#   3,
#   1,
#   2,
#   2,
#   1,
#   1,
#   3,
#   3,
#   1,
#   2,
#   1,
#   3,
#   3,
#   2,
#   1,
#   1,
#   3,
#   1,
#   2,
#   3,
#   3,
#   2,
#   3,
#   3,
#   1,
#   2,
#   3,
#   2,
#   1,
#   3,
#   1,
#   2,
#   1,
#   1,
#   2,
#   3,
#   2,
#   3,
#   2,
#   3,
#   2,
#   1,
#   3,
#   3,
#   3,
#   1,
#   3,
#   2,
#   2,
#   3,
#   1,
#   3,
#   3,
#   3,
#   1,
#   3,
#   1,
#   1,
#   3,
#   3,
#   2,
#   3,
#   3,
#   1,
#   2,
#   3,
#   2,
#   2,
#   3,
#   3,
#   3,
#   1,
#   2,
#   2,
#   1,
#   1,
#   3,
#   2,
#   3,
#   3,
#   1,
#   2,
#   1,
#   3,
#   1,
#   2,
#   3,
#   2,
#   3,
#   1,
#   1,
#   1,
#   3,
#   2,
#   3,
#   1,
#   3,
#   2,
#   1,
#   3,
#   2,
#   2,
#   3,
#   2,
#   3,
#   2,
#   1,
#   1,
#   3,
#   1,
#   3,
#   2,
#   2,
#   2,
#   3,
#   2,
#   2,
#   1,
#   2,
#   2,
#   3,
#   1,
#   3,
#   3,
#   2,
#   1,
#   1,
#   1,
#   2,
#   1,
#   3,
#   3,
#   3,
#   3,
#   2,
#   1,
#   1,
#   1,
#   2,
#   3,
#   2,
#   1,
#   3,
#   1,
#   3,
#   2,
#   2,
#   3,
#   1,
#   3,
#   1,
#   1,
#   2,
#   1,
#   2,
#   2,
#   1,
#   3,
#   1,
#   3,
#   2,
#   3,
#   1,
#   2,
#   3,
#   1,
#   1,
#   1,
#   1,
#   2,
#   3,
#   2,
#   2,
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   3,
#   3,
#   2,
#   1,
#   1,
#   1,
#   2,
#   2,
#   3,
#   1,
#   1,
#   1,
#   2,
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   2,
#   2,
#   3,
#   2,
#   3,
#   3,
#   3,
#   3,
#   1,
#   2,
#   3,
#   1,
#   1,
#   1,
#   3,
#   1,
#   3,
#   2,
#   2,
#   1,
#   3,
#   1,
#   3,
#   2,
#   2,
#   1,
#   2,
#   2,
#   3,
#   1,
#   3,
#   2,
#   1,
#   1,
#   3,
#   3,
#   2,
#   3,
#   3,
#   2,
#   3,
#   1,
#   3,
#   1,
#   3,
#   3,
#   1,
#   3,
#   2,
#   1,
#   3,
#   1,
#   3,
#   2,
#   1,
#   2,
#   2,
#   1,
#   3,
#   1,
#   1,
#   3,
#   3,
#   2,
#   2,
#   3,
#   1,
#   2,
#   3,
#   3,
#   2,
#   2,
#   1,
#   1,
#   1,
#   1,
#   3,
#   2,
#   1,
#   1,
#   3,
#   2,
#   1,
#   1,
#   3,
#   3,
#   3,
#   2,
#   3,
#   2,
#   1,
#   1,
#   1,
#   1,
#   1,
#   3,
#   2,
#   2,
#   1,
#   2,
#   1,
#   3,
#   2,
#   1,
#   3,
#   2,
#   1,
#   3,
#   1,
#   1,
#   3,
#   3,
#   3,
#   3,
#   2,
#   1,
#   1,
#   2,
#   1,
#   3,
#   3,
#   2,
#   1,
#   2,
#   3,
#   2,
#   1,
#   2,
#   2,
#   2,
#   1,
#   1,
#   3,
#   1,
#   1,
#   2,
#   3,
#   1,
#   1,
#   2,
#   3,
#   1,
#   3,
#   1,
#   1,
#   2,
#   2,
#   1,
#   2,
#   2,
#   2,
#   3,
#   1,
#   1,
#   1,
#   3,
#   1,
#   3,
#   1,
#   3,
#   3,
#   1,
#   1,
#   1,
#   3,
#   2,
#   3,
#   3,
#   2,
#   2,
#   1,
#   1,
#   1,
#   2,
#   1,
#   2,
#   2,
#   3,
#   3,
#   3,
#   1,
#   1,
#   3,
#   3,
#   2,
#   3,
#   3,
#   2,
#   3,
#   3,
#   3,
#   2,
#   3,
#   3,
#   1,
#   2,
#   3,
#   2,
#   1,
#   1,
#   1,
#   1,
#   3,
#   3,
#   3,
#   3,
#   2,
#   1,
#   1,
#   1,
#   1,
#   3,
#   1,
#   1,
#   2,
#   1,
#   1,
#   2,
#   3,
#   2,
#   1,
#   2,
#   2,
#   2,
#   3,
#   2,
#   1,
#   3,
#   2,
#   3,
#   2,
#   3,
#   2,
#   1,
#   1,
#   2,
#   3,
#   1,
#   3,
#   3,
#   3,
#   1,
#   2,
#   1,
#   2,
#   2,
#   1,
#   2,
#   2,
#   2,
#   2,
#   2,
#   3,
#   2,
#   1,
#   3,
#   3,
#   2,
#   2,
#   2,
#   3,
#   1,
#   2,
#   1,
#   1,
#   3,
#   2,
#   3,
#   2,
#   3,
#   2,
#   3,
#   3,
#   2,
#   2,
#   1,
#   3,
#   1,
#   2,
#   1,
#   3,
#   1,
#   1,
#   1,
#   3,
#   1,
#   1,
#   3,
#   3,
#   2,
#   2,
#   1,
#   3,
#   1,
#   1,
#   3,
#   2,
#   3,
#   1,
#   1,
#   3,
#   1,
#   3,
#   3,
#   1,
#   2,
#   3,
#   1,
#   3,
#   1,
#   1,
#   2,
#   1,
#   3,
#   1,
#   1,
#   1,
#   1,
#   2,
#   1,
#   3,
#   1,
#   2,
#   1,
#   3,
#   1,
#   3,
#   1,
#   1,
#   2,
#   2,
#   2,
#   3,
#   2,
#   2,
#   1,
#   2,
#   3,
#   3,
#   2,
#   3,
#   3,
#   3,
#   2,
#   3,
#   3,
#   1,
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   2,
#   3,
#   2,
#   2,
#   1,
#   2,
#   2,
#   1,
#   3,
#   1,
#   3,
#   3,
#   3,
#   2,
#   2,
#   3,
#   3,
#   1,
#   2,
#   2,
#   2,
#   3,
#   1,
#   2,
#   1,
#   3,
#   1,
#   2,
#   3,
#   1,
#   1,
#   1,
#   2,
#   2,
#   3,
#   1,
#   3,
#   1,
#   1,
#   3,
#   1,
#   2,
#   3,
#   1,
#   2,
#   3,
#   1,
#   2,
#   3,
#   2,
#   2,
#   2,
#   3,
#   1,
#   3,
#   1,
#   2,
#   3,
#   2,
#   2,
#   3,
#   1,
#   2,
#   3,
#   2,
#   3,
#   1,
#   2,
#   2,
#   3,
#   1,
#   1,
#   1,
#   2,
#   2,
#   1,
#   1,
#   2,
#   1,
#   2,
#   1,
#   2,
#   3,
#   2,
#   1,
#   3,
#   3,
#   3,
#   1,
#   1,
#   3,
#   1,
#   2,
#   3,
#   3,
#   2,
#   2,
#   2,
#   1,
#   2,
#   3,
#   2,
#   2,
#   3,
#   2,
#   2,
#   2,
#   3,
#   3,
#   2,
#   1,
#   3,
#   2,
#   1,
#   3,
#   3,
#   1,
#   2,
#   3,
#   2,
#   1,
#   3,
#   3,
#   3,
#   1,
#   2,
#   2,
#   2,
#   3,
#   2,
#   3,
#   3,
#   1,
#   2,
#   1,
#   1,
#   2,
#   1,
#   3,
#   1,
#   2,
#   2,
#   1,
#   3,
#   2,
#   1,
#   3,
#   3,
#   2,
#   2,
#   2,
#   1,
#   2,
#   2,
#   1,
#   3,
#   1,
#   3,
#   1,
#   3,
#   3,
#   1,
#   1,
#   2,
#   3,
#   2,
#   2,
#   3,
#   1,
#   1,
#   1,
#   1,
#   3,
#   2,
#   2,
#   1,
#   3,
#   1,
#   2,
#   3,
#   1,
#   3,
#   1,
#   3,
#   1,
#   1,
#   3,
#   2,
#   3,
#   1,
#   1,
#   3,
#   3,
#   3,
#   3,
#   1,
#   3,
#   2,
#   2,
#   1,
#   1,
#   3,
#   3,
#   2,
#   2,
#   2,
#   1,
#   2,
#   1,
#   2,
#   1,
#   3,
#   2,
#   1,
#   2,
#   2,
#   3,
#   1,
#   2,
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   1,
#   2,
#   3,
#   3,
#   2,
#   3,
#   1,
#   1,
#   3,
#   3,
#   1,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   1,
#   3,
#   3,
#   3,
#   3,
#   3,
#   1,
#   1,
#   3,
#   2,
#   1,
#   2,
#   1,
#   2,
#   2,
#   3,
#   2,
#   2,
#   2,
#   3,
#   1,
#   2,
#   1,
#   2,
#   2,
#   1,
#   1,
#   2,
#   3,
#   3,
#   1,
#   1,
#   1,
#   1,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   1,
#   3,
#   3,
#   2,
#   3,
#   2,
#   3,
#   3,
#   2,
#   2,
#   1,
#   1,
#   1,
#   3,
#   3,
#   1,
#   1,
#   1,
#   3,
#   3,
#   2,
#   1,
#   2,
#   1,
#   1,
#   2,
#   2,
#   1,
#   1,
#   1,
#   3,
#   1,
#   1,
#   2,
#   3,
#   2,
#   2,
#   1,
#   3,
#   1,
#   2,
#   3,
#   1,
#   2,
#   2,
#   2,
#   2,
#   3,
#   2,
#   3,
#   3,
#   1,
#   2,
#   1,
#   2,
#   3,
#   1,
#   3,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   3,
#   2,
#   2,
#   2,
#   2,
#   2,
#   1,
#   3,
#   3,
#   3])

# %% [markdown]
# Matplotlib散点图

# %%
import matplotlib
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(datingDataMat[:,1],datingDataMat[:2])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-4169d55fbcc2> in <module>
#       2 import matplotlib.pyplot as plt
#       3 fig = plt.figure()
# ----> 4 ax = fig.add_subplot(111)
#       5 ax.scatter(datingDataMat[:,1],datingDataMat[:2])
#       6 plt.show()
#
# F:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# F:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      68
#      69         # _axes_class is set in the subplot_class_factory
# ---> 70         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      71         # add a layout box to this, for both the full axis, and the poss
#      72         # of the axis.  We need both because the axes may become smaller
#
# F:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     473         self.set_axes_locator(kwargs.get("axes_locator", None))
#     474
# --> 475         self.spines = self._gen_axes_spines()
#     476
#     477         # this call may differ for non-sep axes, e.g., polar
#
# F:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _gen_axes_spines(self, locations, offset, units)
#     955         """
#     956         return OrderedDict((side, mspines.Spine.linear_spine(self, side))
# --> 957                            for side in ['left', 'right', 'bottom', 'top'])
#     958
#     959     def cla(self):
#
# F:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     955         """
#     956         return OrderedDict((side, mspines.Spine.linear_spine(self, side))
# --> 957                            for side in ['left', 'right', 'bottom', 'top'])
#     958
#     959     def cla(self):
#
# F:\ProgramData\Anaconda3\lib\site-packages\matplotlib\spines.py in linear_spine(cls, axes, spine_type, **kwargs)
#     499         else:
#     500             raise ValueError('unable to make path for spine "%s"' % spine_type)
# --> 501         result = cls(axes, spine_type, path, **kwargs)
#     502         result.set_visible(rcParams['axes.spines.{0}'.format(spine_type)])
#     503
#
# F:\ProgramData\Anaconda3\lib\site-packages\matplotlib\spines.py in __init__(self, axes, spine_type, path, **kwargs)
#      64         # them pass through the spines machinery without errors.)
#      65         self._position = None
# ---> 66         if not isinstance(path, matplotlib.path.Path):
#      67             raise ValueError(
#      68                 "'path' must be an instance of 'matplotlib.path.Path'")
#
# AttributeError: module 'matplotlib' has no attribute 'path'
