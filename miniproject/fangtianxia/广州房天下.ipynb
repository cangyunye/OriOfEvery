# %% [markdown]
# # 楼盘页信息
#
# 以香江天赋页为例，开发思路如下：
# 1. 从具体楼盘页开始获取信息
# 2. 从具体楼盘页获取详情页和户型页
# 3. 获取详情页信息
# 4. 获取户型页信息
# 5. 打印excel
# 6. 保存sqlite3
# 7. 进行机器学习算法流程
#
# ## 导入模块

# %%
import requests
import re
from pyquery import PyQuery as pq
import random

# %% [markdown]
# ## 定位楼盘首页
#
# 1. 预设首页
#
# 2. 设置随机User-Agent，进行低级防反爬操作

# %%
url = 'http://xiangjiangtianfu.fang.com/'
url_detail = 'http://xiangjiangtianfu.fang.com/house/2811174364/housedetail.htm'
url_huxing = 'https://xiangjiangtianfu.fang.com/photo/list_900_2811174364.htm'
url_base = 'https://gz.newhouse.fang.com/house/s/'

# %%
user_agent_list = [
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
    "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
    "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
    "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
]

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Host': 'xiangjiangtianfu.fang.com',
    'Referer': 'http://gz.newhouse.fang.com/house/s/',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': random.choice(user_agent_list)
}

# %% [markdown]
# ## 网页解码
#
# 房天下的网页直接get的话，会发现源码中文部分无法解析，从网上查询到可以用**gb18030**解码，那就无需过多费事了

# %%
rq = requests.get(url, headers=headers)
doc = pq(rq.content.decode('gb18030'))

# %% [markdown]
# ### 其他解码方法
# ```python
# #gzip解压缩
# import gzip
# import urllib
# req = urllib.request.Request(url=url,headers=headers,method='GET')
# content_ori = urllib.request.urlopen(req).read()
# content = gzip.decompress(content_ori).decode("gb18030")
#
# #转换为latin-1,二进制形式
# content=rq.text.encode('latin-1').decode("gb18030")
# #有没有发现是多此一举，没错直接使用content属性获取的即为二进制，无需在编码为latin-1了，此处仅供参考
# ```

# %% [markdown]
# ### 导航栏信息
#
# 为了方便的通过首页即可定位其他信息页，我们直接从导航栏下手。获取其中另外两个关键信息页。
#
# 1. 定位导航栏
# 2. 获取楼盘详情页
# 3. 获取户型页

# %% [markdown]
# ### 页面信息定位
# #### pyquery进行selector定位
#
# 便捷的方式即通过chrome等等浏览器的开发者模式在**Elements**页，对节点右键copy Selector，然后通过PyQuery方法实现定位。
# ```python
# from pyquery import PyQuery as pq
# #pq解析html源码
# doc=pq(html)
# #寻找selector
# nav=doc('#orginalNaviBox a')
# ```
# #### etree进行xpath定位
#
# ```python
#
# from lxml import etree
# et=etree.HTML(content)
# et.xpath('/html/body/div[3]/div[3]/div[2]/div[1]/div[2]/div[2]/a[1]/div/p[1]/text()')
#
# ```

# %%
# 首页导航
nav = doc('#orginalNaviBox a')
url_detail = 'https:'+nav.eq(1).attr('href')
url_huxing = 'https:'+nav.eq(2).attr('href')
print(url_detail)
print(url_huxing)
# Out:
# https://xiangjiangtianfu.fang.com/house/2811174364/housedetail.htm
# https://xiangjiangtianfu.fang.com/house/2811174364/dongtai.htm

# %% [markdown]
# ### 首页信息打印
# 1. 楼盘名称
# 2. 别名
# 3. 均价
# 4. 价格说明
# 5. 地图api信息获取经纬度

# %%
house = doc('body > div.main_1200.tf > div.firstbox > div.firstright.fr > div.information > div.inf_left1 > div > h1 > strong').text()
alias = doc('body > div.main_1200.tf > div.firstbox > div.firstright.fr > div.information > div.inf_left1 > div > span').text()
price = doc('body > div.main_1200.tf > div.firstbox > div.firstright.fr > div.information > div:nth-child(2) > div.inf_left.fl > span').text()
price_detail = doc(
    'body > div.main_1200.tf > div.firstbox > div.firstright.fr > div.information > div:nth-child(2) > div.inf_right.fl.pr > a.pra01.fl > div > p:nth-child(2)').text()
print(house)
print(alias)
print(price)
print(price_detail)

# %%
info = doc(
    'body > div.main_1200.tf > div.firstbox > div.firstright.fr > div.information')
alias = doc('.fnzoushi01').text()
alias
# Out:
# '香江天赋在售建面为98-127平米的咬合复式4-5房，带装修，带全屋中央空调，均价28000元/平。\n报价时间：2019-03-22 价格有效期：14天'

# %% [markdown]
# ## 楼盘详情页

# %%
req_d = requests.get(url_detail, headers=headers)
doc_d = pq(req_d.content.decode("gb18030"))

# %%
# 全部信息
print(doc_d(".main-item").eq(0).text())
# Out:
# 基本信息
# 价格： 均价约23900元/平方米
# 用户点评： 4.46 [32条点评]
# 物业类别：
# 普通住宅
# 项目特色：
# 品牌地产
# 建筑类别：
# 塔楼 高层
# 装修状况：
# 非毛坯
# 产权年限：
# 普通住宅:70年
# 环线位置：
# 暂无资料
# 开发 商：
# 增城香江房地产有限公司
# 楼盘地址：
# 广园快速路开创大道
# 销售信息
# 销售状态：
# 在售
# 楼盘优惠：
# 暂无
# 开盘时间：
# 2018年12月30日6栋开盘[开盘时间详情]
# 交房时间：
# 2020年12月6#交房
# 售楼地址：
# 广州广园快速路开创大道北香江天赋
# 咨询电话：
# 400-890-0000 转 885462
# 主力户型：
# 三居(2) 四居(6) 五居(12)
# 预售许可证：
# 预售许可证
# 发证时间
# 绑定楼栋
# 20181174
# 2018-12-27
# 6#
# 周边设施
# 交通地铁： 13号线-新塘。 项目交通路网三横两纵，通达性强。紧邻广园、广深、107国道三干道，距离天河区约24公里。拥开创大道、源章大道两条南北主线，约8公里可达萝岗科学城及新塘中心。距离TOD交通枢纽仅8公里，拥有3条国家高铁（广深高铁、广汕高铁和京九高铁）、2条城际轨道（穗莞深和新白广2条城际轨道）、3条地铁路线（13号、16号和23号）以及有轨电车交汇，珠江新城、东莞、深圳、香港等都距离改项目不远（约38—100公里），形成珠三角半小时生活圈。 公交车两站路直接接驳13号线沙村站，交通核心优势得天独厚，享受极致便利。 项目设有3条楼巴路线，分别是到天河宏发大厦、黄埔文化宫及萝岗科学城皇冠假日酒店，楼巴每天运行，出行无忧。目前项目有4条公交车线路，分别是437（项目开往开发东区，接驳南岗地铁站）、572（项目开往开发西区）、358（项目开往萝岗中心）、新塘6路（项目开往塘中心，接驳沙村地铁站）。
# 幼儿园翡翠绿洲幼儿园、东方绿洲幼儿园。
# 中小学1所小学（翡翠绿洲香江小学）。2所初高中（香江小学初中部、香江中学初中部及高中部）等，香江集团联手省一级育才实验学校创办香江中学，由育才中学直管，实现育才系三校联动，是增城至高升学率学校。其中香江中学国际部重金聘请了美国金牌校长Jeffrey Maher坐镇，开设华南首家AP顶石课程，而2018年的AP班毕业生更是创下78%被美国综合排名前50大学录取的记录。
# 大学项目周边现已落成或在建近20余所优质学校，项目5公里内：广州第二中学选址于项目周边，合生育才学校（500米步行可达的），广州二中系增城区应元学校（距离项目2.5公里），英国四大公学之一的费德斯（距离项目2.7公里），项目5-10公里内：美国格兰纳达山特许学校，修仕倍励实验学校，广州南方中英文学校等学校，形成了10公里的教育长廊，名校塔尖教育荟萃林立。
# 综合商场克拉U街、克拉街市、乐家生鲜。3大城市级超级商圈，珠江新城商圈、天河城商圈、萝岗万达商圈距离项目平均约225公里。
# 医院暨华医院（3.8公里）、广东省水电二局医院（8.6公里）、新塘医院（10公里）、岭南医院-中山大学附属第三医院（14公里）、南方医科大学南方医院增城院区（10公里）。
# 银行建设银行
# 其他周边景观：香江天赋保留原生自然环境，建筑与自然共生，被陈家林原始森林环抱，壮阔的天然森林，藏风聚气，山林湖泊密布，呈现5000个/cm3负离子。每一次呼吸都是一种享受。
# 小区内部配套幼儿园、运动场地、游泳池
# 小区规划
# 占地面积：
# 96784平方米
# 建筑面积：
# 378211平方米
# 容积率：
# 3.00
# 绿化率：
# 30%
# 停车位：
# 电梯
# 楼栋总数：
# 暂无资料
# 总户数：
# 暂无资料
# 物业公司：
# 增城香江物业管理有限公司
# 物业费：
# 暂无资料
# 物业费描述：
# 暂无资料
# 楼层状况：
# 查看价格走势 > 价格信息
# 记录时间
# 均价
# 起价
# 价格描述
# 2019-01-06
# 约23900元/㎡
# 约23000元/㎡
# 香江天赋在售88-127㎡复式和平层产品，平层单位均价23000元/平，复式单位均价24800元/平，带装修出售。
# 2018-12-30
# 约23900元/㎡
# 约23000元/㎡
# 香江天赋在售复式及平层单位，88㎡三房平层单位均价23000元/平，98-127㎡四房或五房复式单位均价24800元/平，均为带装修出售。
# 2018-12-17
# 香江天赋将推出97-127㎡广州绝版咬合复式产品，户型方正实用，使用率高达100%-110%，独立专梯入户，智能豪装，送全屋中央空调。具体开盘时间和价格待定。
# 展开
# 记录时间
# 均价
# 起价
# 价格描述
# 2019-01-06
# 约23900元/㎡
# 约23000元/㎡
# 香江天赋在售88-127㎡复式和平层产品，平层单位均价23000元/平，复式单位均价24800元/平，带装修出售。
# 2018-12-30
# 约23900元/㎡
# 约23000元/㎡
# 香江天赋在售复式及平层单位，88㎡三房平层单位均价23000元/平，98-127㎡四房或五房复式单位均价24800元/平，均为带装修出售。
# 2018-12-17
# 香江天赋将推出97-127㎡广州绝版咬合复式产品，户型方正实用，使用率高达100%-110%，独立专梯入户，智能豪装，送全屋中央空调。具体开盘时间和价格待定。
# 2018-12-10
# 香江天赋将推建面88-127㎡三至五房咬合复式产品，独立专梯入户，私家入户花园，户型方正实用率高。
# 2018-11-24
# 香江天赋即将推出88-127㎡三至五房复式产品，6米挑高，专梯入户，使用率高达100-110%。预计12月份开盘，目前价格待定。
# 收起
# 项目简介
# 香江天赋，香江集团敬呈“天”字系全新产品。占位粤港澳大湾区核心城市区位，毗邻TOD国际商业新城，坐拥成熟轨道及路网交通。产品一脉相承香江地产的匠心血统，凝聚翡翠绿洲16年大城修为，为广州东悉心呈现一个咬合式复式墅居产品。产品匠造咬合复式、平层错位挑空的设计，真正实现四开间朝南、6米高挑阳台，私密全套房主人空间，比同等面积段产品拥有更高的使用空间，让洋房享受墅级生活。此外还打造全景开窗设计，无时无刻都能享受一流景观。
# 香江天赋项目总建筑面积约37万平，绿化率达30%，容积率仅3。本项目一线北靠万亩陈家林，南低北高住宅布局，超8000㎡园林景观，区内无边泳池、多功能运动场、夜光跑道、康乐运动场、亲子乐园等休闲人居设计，无忧生活。项目拥有18年一站式家门口教育，直接连通国际化教育。香江天赋涵盖87-127㎡平层、复式，因私家入户电梯和创新咬合复式的设计，房屋使用率高达100%-110%。遵循“以匠心，致不凡”的营造标准，全项目在规划、建筑、景观、智能化四大层面极力打造天工精品：满屋一线品牌交标，真正国际品牌全屋中央空调豪宅交标，配备全屋新风系统，形成“强制排风，自然进风”的对流，让每家每户业主与万顷山林同呼吸。八重智能安防系统、智能入户系统构筑智能化社区，周际配置24小时安防脉冲，25处无死角远程监控，21处电子巡更,提升效率及服务品质。九重智能家居系统，室内配备智能灯控、居室兑奖、居室安防、智能监护等多项智能化服务。智能人脸识别梯控，独立入户：专属电梯直达入户花园，尊贵、舒适、私密、安全，畅享质感墅感生活，以精工巨匠之作，致敬粤港澳大湾区之芯。

# %% [markdown]
# ### 详情页基本信息

# %%
# 基本信息
basic_info = doc_d(".main-item").eq(0)
price = basic_info(".main-info-price")('em').text()
dianping_href = basic_info(".main-info-comment")('a').attr('href')
dianping = basic_info(".main-info-comment")('span').eq(2).text()
list_clearfix = basic_info("ul li")  # basic_info(".list.clearfix")
wuyeleibie = list_clearfix.eq(0)(".list-right").text()
xiangmutese = list_clearfix.eq(1)(".list-right")(".tag").text()
jianzhuleibie = list_clearfix.eq(2)(".list-right").text()
zhuangxiu = list_clearfix.eq(3)(".list-right").text()
chanquan = list_clearfix.eq(4)(".list-right").text()
huanxianweizhi = list_clearfix.eq(5)(".list-right").text()
kaifashang = list_clearfix.eq(6)(".list-right-text").text()
loupandizhi = list_clearfix.eq(7)(".list-right-text").text()
print(price)
print(dianping_href)
print(dianping)
print(wuyeleibie)
print(xiangmutese)
print(jianzhuleibie)
print(zhuangxiu)
print(chanquan)
print(huanxianweizhi)
print(kaifashang)
print(loupandizhi)
# Out:
# 均价约28000元/平方米
# //xiangjiangtianfu.fang.com/dianping/
# 4.23
# 普通住宅
# 品牌地产
# 塔楼 高层
# 非毛坯
# 普通住宅:70年
# 暂无资料
# 增城香江房地产有限公司
# 广园快速路开创大道

# %% [markdown]
# ### 详情页销售信息

# %%
# 销售信息
sale_info = doc_d(".main-item").eq(1)
list_clearfix = sale_info(".list.clearfix")('li')
sale_status = list_clearfix.eq(0)(".list-right").text()
youhui = list_clearfix.eq(1)(".list-right").text()
kaipanshijian = list_clearfix.eq(2)(".list-right").text()
jiaofangdate = list_clearfix.eq(3)(".list-right").text()
salesaddr = list_clearfix.eq(4)(".list-right").text()
zixun = list_clearfix.eq(5)(".list-right").text()
zhulihuxing = list_clearfix.eq(6)(".list-right-text").text()

print(sale_status)
print(youhui)
print(kaipanshijian)
print(jiaofangdate)
print(salesaddr)
print(zixun)
print(zhulihuxing)
# Out:
# 在售
# 暂无
# 2018年12月30日6栋开盘[开盘时间详情]
# 2020年12月6#交房
# 广州广园快速路开创大道北香江天赋
# 400-890-0000 转 885462
# 三居(2) 四居(6) 五居(12)

# %% [markdown]
# ### 详情页周边设施

# %%
# 周边设施
surroundingfacility = doc_d(".main-item").eq(2)
list_clearfix = surroundingfacility(".sheshi_zb")('li')
traffic = list_clearfix.eq(0).text()
kindergarten = list_clearfix.eq(1).text()
middleschool = list_clearfix.eq(2).text()
univercity = list_clearfix.eq(3).text()
coodepartment = list_clearfix.eq(4).text()
hospital = list_clearfix.eq(5).text()
bank = list_clearfix.eq(6).text()
rest = list_clearfix.eq(7).text()
facilities = list_clearfix.eq(8).text()
print(traffic)
print(kindergarten)
print(middleschool)
print(univercity)
print(coodepartment)
print(hospital)
print(bank)
print(rest)
print(facilities)
# Out:
# 交通地铁： 13号线-新塘。 项目交通路网三横两纵，通达性强。紧邻广园、广深、107国道三干道，距离天河区约24公里。拥开创大道、源章大道两条南北主线，约8公里可达萝岗科学城及新塘中心。距离TOD交通枢纽仅8公里，拥有3条国家高铁（广深高铁、广汕高铁和京九高铁）、2条城际轨道（穗莞深和新白广2条城际轨道）、3条地铁路线（13号、16号和23号）以及有轨电车交汇，珠江新城、东莞、深圳、香港等都距离改项目不远（约38—100公里），形成珠三角半小时生活圈。 公交车两站路直接接驳13号线沙村站，交通核心优势得天独厚，享受极致便利。 项目设有3条楼巴路线，分别是到天河宏发大厦、黄埔文化宫及萝岗科学城皇冠假日酒店，楼巴每天运行，出行无忧。目前项目有4条公交车线路，分别是437（项目开往开发东区，接驳南岗地铁站）、572（项目开往开发西区）、358（项目开往萝岗中心）、新塘6路（项目开往塘中心，接驳沙村地铁站）。
# 幼儿园翡翠绿洲幼儿园、东方绿洲幼儿园。
# 中小学1所小学（翡翠绿洲香江小学）。2所初高中（香江小学初中部、香江中学初中部及高中部）等，香江集团联手省一级育才实验学校创办香江中学，由育才中学直管，实现育才系三校联动，是增城至高升学率学校。其中香江中学国际部重金聘请了美国金牌校长Jeffrey Maher坐镇，开设华南首家AP顶石课程，而2018年的AP班毕业生更是创下78%被美国综合排名前50大学录取的记录。
# 大学项目周边现已落成或在建近20余所优质学校，项目5公里内：广州第二中学选址于项目周边，合生育才学校（500米步行可达的），广州二中系增城区应元学校（距离项目2.5公里），英国四大公学之一的费德斯（距离项目2.7公里），项目5-10公里内：美国格兰纳达山特许学校，修仕倍励实验学校，广州南方中英文学校等学校，形成了10公里的教育长廊，名校塔尖教育荟萃林立。
# 综合商场克拉U街、克拉街市、乐家生鲜。3大城市级超级商圈，珠江新城商圈、天河城商圈、萝岗万达商圈距离项目平均约225公里。
# 医院暨华医院（3.8公里）、广东省水电二局医院（8.6公里）、新塘医院（10公里）、岭南医院-中山大学附属第三医院（14公里）、南方医科大学南方医院增城院区（10公里）。
# 银行建设银行
# 其他周边景观：香江天赋保留原生自然环境，建筑与自然共生，被陈家林原始森林环抱，壮阔的天然森林，藏风聚气，山林湖泊密布，呈现5000个/cm3负离子。每一次呼吸都是一种享受。
# 小区内部配套幼儿园、运动场地、游泳池

# %% [markdown]
# ### 详情页价格信息

# %%
# 价格信息,这里没什么好看的
price = doc_d(".main-item").eq(4)
print(price)
# Out:
# <div class="main-item">
#             	<h3>
#                    <a href="//xiangjiangtianfu.fang.com/house/2811174364/fangjia.htm" target="_blank" class="price-trend">查看价格走势 &gt;</a>
#                 	价格信息
#                 </h3>
#                 <div class="main-table">
#                     <div class="table-part">
#                        <table cellpadding="0" cellspacing="0">
#                           <tr>
#                               <td width="110">记录时间</td>
#                               <td width="90">均价</td>
#                               <td width="90">起价</td>
#                               <td width="342">价格描述</td>
#                           </tr>
# 						  															 <tr>
# 						        <td>2019-01-06</td>
# 						        <td>约23900元/㎡</td>
# 						        <td>约23000元/㎡</td>
# 						        <td class="td-left">香江天赋在售88-127㎡复式和平层产品，平层单位均价23000元/平，复式单位均价24800元/平，带装修出售。</td>
# 								</tr>
# 													  															 <tr>
# 						        <td>2018-12-30</td>
# 						        <td>约23900元/㎡</td>
# 						        <td>约23000元/㎡</td>
# 						        <td class="td-left">香江天赋在售复式及平层单位，88㎡三房平层单位均价23000元/平，98-127㎡四房或五房复式单位均价24800元/平，均为带装修出售。</td>
# 								</tr>
# 													  															 <tr>
# 						        <td>2018-12-17</td>
# 						        <td> </td>
# 						        <td> </td>
# 						        <td class="td-left">香江天赋将推出97-127㎡广州绝版咬合复式产品，户型方正实用，使用率高达100%-110%，独立专梯入户，智能豪装，送全屋中央空调。具体开盘时间和价格待定。</td>
# 								</tr>
# 													  													  													                         </table>
# 					                          <div class="btn-open">展开<i></i></div>
# 					                       </div>
# 					                    <div class="table-all" style="display: none;">
#                     	<table cellpadding="0" cellspacing="0">
#                           <tr>
#                               <td width="110">记录时间</td>
#                               <td width="90">均价</td>
#                               <td width="90">起价</td>
#                               <td width="342">价格描述</td>
#                           </tr>
#                          								 <tr>
# 						        <td>2019-01-06</td>
# 						        <td>约23900元/㎡</td>
# 						        <td>约23000元/㎡</td>
# 						        <td class="td-left">香江天赋在售88-127㎡复式和平层产品，平层单位均价23000元/平，复式单位均价24800元/平，带装修出售。</td>
# 								</tr>
# 						  								 <tr>
# 						        <td>2018-12-30</td>
# 						        <td>约23900元/㎡</td>
# 						        <td>约23000元/㎡</td>
# 						        <td class="td-left">香江天赋在售复式及平层单位，88㎡三房平层单位均价23000元/平，98-127㎡四房或五房复式单位均价24800元/平，均为带装修出售。</td>
# 								</tr>
# 						  								 <tr>
# 						        <td>2018-12-17</td>
# 						        <td> </td>
# 						        <td> </td>
# 						        <td class="td-left">香江天赋将推出97-127㎡广州绝版咬合复式产品，户型方正实用，使用率高达100%-110%，独立专梯入户，智能豪装，送全屋中央空调。具体开盘时间和价格待定。</td>
# 								</tr>
# 						  								 <tr>
# 						        <td>2018-12-10</td>
# 						        <td> </td>
# 						        <td> </td>
# 						        <td class="td-left">香江天赋将推建面88-127㎡三至五房咬合复式产品，独立专梯入户，私家入户花园，户型方正实用率高。</td>
# 								</tr>
# 						  								 <tr>
# 						        <td>2018-11-24</td>
# 						        <td> </td>
# 						        <td> </td>
# 						        <td class="td-left">香江天赋即将推出88-127㎡三至五房复式产品，6米挑高，专梯入户，使用率高达100-110%。预计12月份开盘，目前价格待定。</td>
# 								</tr>
# 						                         </table>
#                        <div class="btn-off">收起<i></i></div>
#                     </div>
# 					                </div>
#             </div>

# %% [markdown]
# ## 户型页
#
# ### 获取ajax返回json数据

# %%
req_h = requests.get(url_huxing, headers=headers)
doc_h = pq(req_h.content.decode("gb18030"))

# %%
from urllib.parse import quote, unquote, urlencode
huxing_list = doc_h('.xc_list').text()
query_string = {
    'newcode': url_detail.split('/')[-2],
    'count': 'false',
    'start': 12,
    'limit': 12,
    'room': 'all',
    'city': unquote('广州')
}
url_house = url+"house/ajaxrequest/householdlist_get.php?"
print(url_house)
headers = {
    'Referer': 'https://xiangjiangtianfu.fang.com/photo/list_900_2811174364.htm',
    'User-Agent': random.choice(user_agent_list),
    'x-requested-with': 'XMLHttpRequest'
}
houses_ajax = requests.get(url_house, params=query_string, headers=headers)
# Out:
# http://xiangjiangtianfu.fang.com/house/ajaxrequest/householdlist_get.php?

# %%
houses_ajax.json()
# Out:
# "[{'reference_price': '186.21', 'reference_price_type': '万元/套', 'IntervalPrice': '0-0', 'IntervalPriceType': '万元/套', 'picID': '162591237', 'hx_score': '4.60', 'fz_score': '5.00', 'cg_score': '5.00', 'bj_score': '4.00', 'cc_score': '5.00', 'df_score': '4.00', 'hx_desp': '整体户型方正，活动区域开阔，居住舒适度高；整个空间全明通透，采光良好，同时利于居住空间通风；卫生间门朝向主要活动区域；客厅、卧室、卫生间和厨房等主要功能间的尺寸以及比例适中，有利于采光和通风，居住起来舒适、方便；公摊高于15%且低于25%，符合住宅公摊正常范围。', 'huxing_feature': '主卧带卫,观景飘窗,干湿分离', 'room': '3', 'hall': '2', 'toilet': '2', 'kitchen': '1', 'buildingarea': '99.31', 'huxing_saling': '1', 'houseimageurl': '//imgs.soufunimg.com/viewimage/house/2015_07/21/gz/1437446236036_000/220x150.jpg', 'housetitle': 'A10/A11栋03户型', 'pic_sort': '300', 'updatedate': '2017-12-04 10:11:05', 'livingarea': '0.00', 'id': '0', 'open_type': '', 'price_interface_show': 'y', 'status': '在售', 'style': '', 'typearea': '建面', 'hxtNum': '', 'onsaleNum': {'OnsaleNum': ''}}, {'reference_price': '94.77', 'reference_price_type': '万元/套', 'IntervalPrice': '0-0', 'IntervalPriceType': '万元/套', 'picID': '162591224', 'hx_score': '4.50', 'fz_score': '5.00', 'cg_score': '4.50', 'bj_score': '4.00', 'cc_score': '5.00', 'df_score': '4.00', 'hx_desp': '整体户型方正，活动区域开阔，居住舒适度高；户型不是南北通透，整体空间无穿堂风；卫生间门朝向主要活动区域，私密性一般；各个功能区的尺寸比例规范，布局合理，能很好地满足日常功能需求，整体空间开阔，采光充足，居住舒适度好；公摊高于15%且低于25%，符合住宅公摊正常范围。', 'huxing_feature': '主卧带卫,厨卫不对门,双阳台', 'room': '3', 'hall': '2', 'toilet': '2', 'kitchen': '1', 'buildingarea': '99.76', 'huxing_saling': '1', 'houseimageurl': '//imgs.soufunimg.com/viewimage/house/2015_07/21/gz/1437446231941_000/220x150.jpg', 'housetitle': 'A8/A9栋01户型', 'pic_sort': '100', 'updatedate': '2017-12-04 10:14:14', 'livingarea': '83.79', 'id': '0', 'open_type': '', 'price_interface_show': 'y', 'status': '在售', 'style': '', 'typearea': '建面', 'hxtNum': '', 'onsaleNum': {'OnsaleNum': ''}}, {'reference_price': '157.95', 'reference_price_type': '万元/套', 'IntervalPrice': '0-0', 'IntervalPriceType': '万元/套', 'picID': '202008477', 'hx_score': '4.80', 'fz_score': '5.00', 'cg_score': '5.00', 'bj_score': '5.00', 'cc_score': '4.00', 'df_score': '5.00', 'hx_desp': '各个空间户型方正，后期空间利用率高；全明通透户型，居住舒适度较高，整个空间采光充足，利于后期居住；整个户型空间布局合理，做到了干湿分离、动静分离，方便后期生活；卫生间空间不算开阔，基本满足使用功能。', 'huxing_feature': '户型方正,卧室朝南,厨卫不对门', 'room': '2', 'hall': '2', 'toilet': '1', 'kitchen': '1', 'buildingarea': '84.24', 'huxing_saling': '1', 'houseimageurl': '//img11.soufunimg.com/viewimage/house/2018_12/31/M1B/11/6D/ChCE4Fwp6jKIbfn3AAdBoMiUigUABIxvQCEJlAAB0G4184/220x150.png', 'housetitle': 'A7栋B单元建面84平04户型', 'pic_sort': '70', 'updatedate': '2018-12-31 18:07:19', 'livingarea': '66.03', 'id': '0', 'open_type': '', 'price_interface_show': 'y', 'status': '在售', 'style': '', 'typearea': '建面', 'hxtNum': '', 'onsaleNum': {'OnsaleNum': ''}}, {'reference_price': '157.95', 'reference_price_type': '万元/套', 'IntervalPrice': '', 'IntervalPriceType': '万元/套', 'picID': '202016267', 'hx_score': '0.00', 'fz_score': '0.00', 'cg_score': '0.00', 'bj_score': '0.00', 'cc_score': '0.00', 'df_score': '0.00', 'hx_desp': '', 'huxing_feature': '户型方正,卧室朝南,厨卫不对门', 'room': '2', 'hall': '2', 'toilet': '1', 'kitchen': '1', 'buildingarea': '84.24', 'huxing_saling': '1', 'houseimageurl': '//img11.soufunimg.com/viewimage/house/2018_12/27/M12/11/60/ChCE4Fwk8hSIP6NXAAWmLp3mzPIABIskAHx3O4ABaZG331/220x150.png', 'housetitle': 'A7栋B单元建面84平03户型', 'pic_sort': '70', 'updatedate': '2018-12-29 13:36:20', 'livingarea': '66.03', 'id': '0', 'open_type': '', 'price_interface_show': 'y', 'status': '在售', 'style': '', 'typearea': '建面', 'hxtNum': '', 'onsaleNum': {'OnsaleNum': ''}}, {'reference_price': '157.95', 'reference_price_type': '万元/套', 'IntervalPrice': '0-0', 'IntervalPriceType': '万元/套', 'picID': '180571978', 'hx_score': '4.40', 'fz_score': '5.00', 'cg_score': '5.00', 'bj_score': '3.00', 'cc_score': '5.00', 'df_score': '4.00', 'hx_desp': '各个空间户型方正，方便室内家具布置；整个空间全明通透，采光良好，同时利于居住空间通风；卧室进卫生间需要穿过餐厅或客厅；卫生间门朝向主要活动区域；各个功能区的尺寸比例规范，布局合理，能很好地满足日常功能需求，整体空间开阔，采光充足，居住舒适度好；公摊高于15%且低于25%，符合住宅公摊正常范围。', 'huxing_feature': '南北通透,动静分离,明厨明卫', 'room': '2', 'h ...

# %% [markdown]
# ### 读写json

# %%
import json
with open('xjtf.json', 'w') as f:
    #     f.writelines(repr(houses_ajax.json()))
    f.writelines(json.dumps(houses_ajax.json(), ensure_ascii=False, indent=4))
with open('xjtf.json', 'r') as f:
    x = json.load(f)

# %% [markdown]
# ### 遍历所有户型页

# %% [markdown]
# ## 参考文档
#
# https://www.jianshu.com/p/639a67bc75b9

# %% [markdown]
# 地图定位api:https://ditu.fang.com/?c=channel&a=ajaxXiaoquMapSearch&x1=113.557556&y1=23.1417&distance=2&strNewCode=2811174364&city=gz

# %% [markdown]
# ### url编码解码

# %%
from urllib.parse import quote, unquote, urlencode
my_data = '广州'
x = '%E5%B9%BF%E5%B7%9E'
# url编码
encode_data = quote(my_data)
print("encode_data : %s " % encode_data)
# url解码
decode_data = unquote(encode_data)
print("decode_data : %s " % decode_data)

my_query = {'conent': '天天向上'}
# url参数编码
encode_query = urlencode(my_query)
print("encode_query : %s " % encode_query)
# url参数解码
decode_query = unquote(encode_query)
print("decode_query : %s " % decode_query)
encode_url = 'http://127.0.0.1?'+encode_query

# url解码
decode_url = unquote(encode_url)
print("decode_url : %s " % decode_url)
# Out:
# encode_data : %E5%B9%BF%E5%B7%9E
# decode_data : 广州
# encode_query : conent=%E5%A4%A9%E5%A4%A9%E5%90%91%E4%B8%8A
# decode_query : conent=天天向上
# decode_url : http://127.0.0.1?conent=天天向上

# %% [markdown]
# ## test

# %%
#直接使用https://gz.newhouse.fang.com/house/s/ 页requests会报无限exceeds 30 次的重定向
#这里我们通过allow_redirects=False控制不让重定向，然后通过headers['Location']取得了实际搜索地址
#但好像还不如构造一次合理的headers来的方便
headers = {
    'authority': 'gz.newhouse.fang.com',
    'Referer':url_base,
    'upgrade-insecure-requests': '1',
    'User-Agent': random.choice(user_agent_list)
}
req_b = requests.get(url_base, headers=headers,allow_redirects=False)
# loc_search = req_b.headers['Location']
# req_b = requests.get(loc_search, headers=headers,allow_redirects=False)
doc_b = pq(req_b.content.decode("gb18030"))

# %%
# 这一层有很多内容
li_s=doc_b('#newhouse_loupai_list ul li')
for i in li_s.items():
    href = i('.nlc_img a').attr('href')
    name = i('.nlc_img a img').eq(1).attr('alt')
    if href :
        # 清理广告会得到的None
        print('https:'+i('.nlc_img a').attr('href'),name)
# Out:
# https://kejixiaozhengfsk.fang.com/ 科慧花园
# https://tianjuanfenglj.fang.com/ 路劲天隽峰
# https://lvhuguojichengmj.fang.com/ 绿湖国际城
# https://yunyixsj.fang.com/ 新世界·云逸
# https://shouzhuhuayuanct.fang.com/ 城投·首筑花园
# https://kaiyuewanxsj.fang.com/ None
# https://dongpoyx.fang.com/ 越秀·东坡
# https://nanhuashidaicheng.fang.com/ 南华时代城
# https://yushanguojihj.fang.com/ 合景誉山国际
# https://930226.fang.com/ 北部万科城
# https://yunshanyipin.fang.com/ 云山壹品
# https://yuexiubaoliaite.fang.com/ 越秀保利爱特城
# https://baolichengns.fang.com/ 南沙保利城
# https://xiangshanhujd.fang.com/ 金地香山湖
# https://yunxisiji.fang.com/ 云溪四季
# https://tianjuguangchang.fang.com/ 中国通号·天聚广场
# https://binhaixinchengyx.fang.com/ 越秀·滨海新城
# https://chunfengshiliwk.fang.com/ 万科春风十里
# https://nanfangshuilianfy.fang.com/ 方圆合景·南沙水恋
# https://174344.fang.com/ 海伦堡海伦湾

# %%
# 获取楼盘页面数
for i in doc_b('.page .fr a').items():
    print(i)
    
print(doc_b('.page .fr .next').attr('href'))
print(doc_b('.page .fr .last').attr('href'))
# Out:
# <a class="active">1</a>
#
# <a href="/house/s/b92/">2</a>
#
# <a href="/house/s/b93/">3</a>
#
# <a href="/house/s/b94/">4</a>
#
# <a href="/house/s/b95/">5</a>
#
# <a href="/house/s/b96/">6</a>
#
# <a href="/house/s/b97/">7</a>
#
# <a href="/house/s/b98/">8</a>
#
# <a href="/house/s/b99/">9</a>
#
#
#
# <a href="javascript:void(0)" style="border:none;cursor:default !important;" class="f16">...</a>
#
# <a class="next" href="/house/s/b92/">下一页</a>
#
# <a class="last" href="/house/s/b929/">尾页</a>
#
# /house/s/b92/
# /house/s/b929/

# %%
doc_b('#sjina_C20_02 > a').attr('href')
# Out:
# '//kejixiaozhengfsk.fang.com/'

# %%
req_b.text.encode('latin-1').decode("gb18030")
# Out:
# '<!doctype html>\n<html>\n<head>\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<meta name="renderer" content="webkit">\n<meta charset="gb2312">\n<meta name="keywords" content="2019广州新房,2019广州新楼盘信息">\n<meta name="description" content="广州新房，现有新楼盘578个，房天下广州新房网为您提供大量优质真实的广州新房出售信息及最新新楼盘房价信息，为您创造最佳新房购房体验。">\n<meta name="author" content="SFun ZBS Team">\n<meta name="location" content="province=澳洲;city=广州;coord=23.1290750,113.2644227;" />\n<meta name="mobile-agent" content="format=html5;url=https://m.fang.com/xf/gz/" />\n<link rel="alternate" media="only screen and(max-width: 640px)" href="https://m.fang.com/xf/gz/" >\t\t\n<meta http-equiv="Content-Language" content="zh-cn">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<meta property="og:type" content="image"/>\n<meta property="og:image" content="//static.soufunimg.com/home/online/common/fanglogo.jpg"/>\n<title>广州新房_广州楼盘_广州房价_广州房产信息网-广州房天下</title>\n\n<script>\nvar city_cookie = 0;\n</script>\n  \n\n<script id="__vb" src="//jsub.fang.com/_vb.js?c=nhlist" type="text/javascript"></script>\n\n<script>\n\tvar newhouseDomain = "//gz.newhouse.fang.com";\n</script>\n\n\n<script type=\'text/javascript\' src=\'//clickm.fang.com/click/new/clickm.js\'></script><script type=\'text/javascript\'>Clickstat.eventAdd(window,\'load\',function(e){Clickstat.batchEvent(\'sjina_\',\'gz\');});</script>\n<script type="text/javascript" src="//static.soufunimg.com/newhouse/js/jquery-1.7.2.min.js"></script>\n\n<script type="text/javascript" src="//static.soufunimg.com/newhouse/js/search_compare_201402.js?v=20181214"></script>\n\n\t\t\n\t\t\n\n<script>\n    ucity = "%B9%E3%D6%DD";\n    ad_lunxun_1=ad_lunxun_2=ad_lunxun_3=ad_lunxun_4=ad_lunxun_5=\'\';\n\tctmpagevalue = \'xf_search\';\n\tisfangliao = \'\';\n</script>\n\n\n\n<script src="//static.soufunimg.com/zbs/newhouse/js/jquery.SuperSlide.2.1.1.js" type="text/javascript"></script>\n\n\n <!--[if IE 6]>\n\n<script type="text/javascript">\nDD_belatedPNG.fix(\'div,img,span,p,a,u,ul,li,h1,h2,h3,h4,h5,h6,i\');\n</script>\n<![endif]--> \n\n\n<!-- css compress begin --><link  type=\'text/css\' rel=\'stylesheet\' href=\'//static.soufunimg.com/??zbs/newhouse/css/sfpc_base.css,newhouse/style/search_header.css,newhouse/style/search_style_201406.css?v=20181022,newhouse/style/search201411.css?v=20181022,newhouse/style/newstyle.css?v=20190319,newhouse/style/sfpc_base.css,newhouse/style/minav_201409.css,newhouse/style/navigation20141112.css,newhouse/style/newstyle_re.css?v=201810221,newhouse/style/css_list.css?v=20181022,newhouse/style/dplist_201501.css?v=20160311,newhouse/style/search_merge.css,navigation/style/navigation20141112.css,homepage/new/family/css/navsupply.css?v=1,newhouse/style/search_sy_201409.css?v=20181022,newhouse/style/loupanSubmit.css?v=201707,newhouse/style/newhouse_footer.css?v=20160318,newhouse/style/rightTools.css?v=20181022\'>\n</head>\n\t\n<body>\n\n<script type=\'text/javascript\'>\nvar xf_adshow_ctrl = \'xfsearch_ad_ctrl\';\nvar indexListShowSeach = true;\nvar js_orderby = "/house/s/b1%3F/";\nvar js_startdate = "/house/s/a4%3F/";\nvar js_fitment = "/house/s/c1%3F/";\n\nvar salingall_link = "/house/s/";\nvar saling1_link = "/house/s/b81/";\nvar saling2_link = "/house/s/b82/";\nvar saling0_link = "/house/s/b80/";\n//360自动推送代码添加\n</script>\n \n<script src="https://jspassport.ssl.qhimg.com/11.0.1.js?734d8fef74bfeb16b4d5cfe0103b2be0" id="sozz"></script>\n\n<div style=" background:#f3f3f3;min-width:1200px;position:relative;">\n\t\t\t\t\t\t\r\n<link rel="dns-prefetch" href="//jsub.fang.com">\r\n<link rel="dns-prefetch" href="//clickm.fang.com">\r\n<link rel="dns-prefetch" href="//countubn.3g.fang.com">\r\n<link rel="dns-prefetch" href="//countpvn.3g.fang.com">\r\n<link rel="dns-prefetch" href="//static.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img.soufunimg.com">\r\n<link rel="dns-prefetch" href="//imgs.soufunimg.com">\r\n<link rel="dns-prefetch" href="//img1.soufunimg.com">\r\n<link rel="dns-prefetch" hr ...
